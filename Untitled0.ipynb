# %% [markdown]
# <a href="https://colab.research.google.com/github/khais43/32697/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TOKENS -- LEXICAL UNIT (SMALLEST)

# %%
# 1. keywords -- PREDEFINED WORDS -- CANNOT BE CHANGED
# 2. identifiers
# 3. literals
# 4. operators
     -- ARETHEMETIC, ASSIGNMENT, BOOLIAN, LOGICAL, IDENTITY
# 5. puntuators
# Out:
#   File "<ipython-input-12-cb8e7ca0e8c5>", line 5
#     -- ARETHEMETIC, ASSIGNMENT, BOOLIAN, LOGICAL, IDENTITY
#     ^
# IndentationError: unexpected indent

# %%
help ('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
23, 5.6, -9.5
#string -- chracr


'23.4', "34"
# Out:
# ('23.4', '34')

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# identifier

var = 12
vaer1 ='gejorbdpgrekd'
print(vaer1)
# Out:
# gejorbdpgrekd

# %%
a = 64
b = 6.3
c = 5+6j

# %%
print(type(a), type (b), type (c))
# Out:
# <class 'int'> <class 'float'> <class 'complex'>

# %%
# operators

# arithemetic

a = 10
b = 5

a+b, a-b, a*b, a/b, a**b, a%b, a//b, 100%b
# Out:
# (15, 5, 50, 2.0, 100000, 0, 2, 0)

# %%
# type casting -- implicit , explict

# relational / comparison

a > b, b<a, a>=b, b<=a, a==b, a!=b
# Out:
# (True, True, True, True, False, True)

# %%
# bool

True, False
# Out:
# (True, False)

# %%
# logical operator
con1 = a>b
con2 = a<b

# %%
True and True, True and False, False and True, False and False
# Out:
# (True, False, False, False)

# %%
True or True, True or False, False or True, False or True
# Out:
# (True, True, True, True)

# %%
name = 'khais'

'A' in name, 'a' not in name
# Out:
# (False, False)

# %%
# heading

# %% [markdown]
# # Data Types
#
# * Numbers - int, float,complex
# * String - str
# * List - list

# %%
# string -- CHARECTORS WEN WILL USE IN PYTHON
# single
X = 'this is a single line string'

# multi line string
y = '''this is
a multi line
strings'''

# %%
# generate x amoumt of meet links

import random, string
pop = string
''.joint (randos)
orefiz - ''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-4c097b39b11b> in <cell line: 5>()
#       3 import random, string
#       4 pop = string
# ----> 5 ''.joint (randos)
#       6 orefiz - ''
#
# AttributeError: 'str' object has no attribute 'joint'

# %%
prefix = 'https://meet.google.com/'

fp = '', join(random.sample(pop, 3))
sp = '', join(random.sample(pop, 4))
tp = '', join(random.sample(pop, 3))
suffix = '-', join((fp, sp, tp))
stop = time,time()
print(prefix+sufix)
print('time took : ',stop-start,'as')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-14d9814cd0c5> in <cell line: 3>()
#       1 prefix = 'https://meet.google.com/'
#       2
# ----> 3 fp = '', join(random.sample(pop, 3))
#       4 sp = '', join(random.sample(pop, 4))
#       5 tp = '', join(random.sample(pop, 3))
#
# NameError: name 'join' is not defined

# %%
x = 'python'

# %%
x[0], x[-3], x[-1:]
# Out:
# ('p', 'h', 'n')

# %%
-6-1
# Out:
# -7

# %%
-6*-1
# Out:
# 6

# %%
file = input('enter a file name:')
print(file)
print(type(file))
# Out:
# enter a file name:sample.txt
# sample.txt
# <class 'str'>

# %%
file.split('.') [-1]
# Out:
# 'txt'

# %%
def file_check(x):

  allowed = ['pdf','docx']

  ext = x.split('.')

if ext [-1] in allowed:
   return ext [-1]
else:
    print('invalid file type -', ext[-1],'type not supported')
# Out:
#   File "<ipython-input-34-e8923573acd3>", line 8
#     return ext [-1]
#     ^
# SyntaxError: 'return' outside function

# %%
def file_check(x):

    allowed = ['pdf', 'docx']

    ext = x.split('.')

    if ext[-1] in allowed:
        return ext[-1]
    else:
        print('Invalid file type -', ext[-1], 'type not supported')

# %%
file_check('slide.pptx')
file_check('resume.pdf')
# Out:
# Invalid file type - pptx type not supported
# 'pdf'

# %%
# assignment

age = input('enter age: ')
age = int(age)

if age>18:
 print('yes')
else:
 print('no')
# Out:
# enter age: 29
# yes

# %%
marks = float(input('enter marks :'))
if marks >=50 and marks<80:
   print(' C Grade')
elif marks>=80 and marks<95:
   print('B Grade')
elif marks>=95 and marks<100:
   print('A Grade')
else:
   print('Grade Not Defined')
# Out:
# enter marks :98
# A Grade

# %%
# Take user input
num = float(input("Enter a number: "))

# Check if the number is positive, negative, or zero
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: 0
# The number is zero.

# %%
# Take user input
num = int(input("Enter a number: "))

# Check if the number is odd or even
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number: 3
# The number is odd.

# %%
# LIST

com = ['A','B','C']

#add  -- append, extend, insert

# append -- 1 element
com.append('D')
com
# Out:
# ['A', 'B', 'C', 'D']

# %%
# extend
com.extend(['H','I','J','K'])
com
# Out:
# ['A', 'B', 'C', 'D', 'H', 'I', 'J', 'K']

# %%
com.append([1,2])
com
# Out:
# ['A', 'B', 'C', 'D', 'H', 'I', 'J', 'K', [1, 2]]

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
# delete element

# pop
com.pop()
# Out:
# [1, 2]

# %%
com
# Out:
# ['A', 'B', 'C', 'D', 'H', 'I', 'J', 'K']

# %%
com.pop()
# Out:
# 'K'

# %%
com
# Out:
# ['A', 'B', 'C', 'D', 'H', 'I', 'J']

# %%
#remove
com.remove('A')
com
# Out:
# ['B', 'C', 'D', 'H', 'I', 'J']

# %%
com.clear()
com
# Out:
# []

# %%
del com

# %%
com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-60ff787b3d2f> in <cell line: 1>()
# ----> 1 com
#
# NameError: name 'com' is not defined

# %%
#copy

com = [1, 2, 3]
cc = com.copy()
cc
# Out:
# [1, 2, 3]

# %%
cc.extend([110, 112, 113])
cc
# Out:
# [1, 2, 3, 110, 112, 113]

# %%
com
# Out:
# [1, 2, 3]

# %%
cc.reverse()

# %%
cc
# Out:
# [113, 112, 110, 3, 2, 1]

# %%
help(list.sort)
# Out:
# Help on method_descriptor:
#
# sort(self, /, *, key=None, reverse=False)
#     Sort the list in ascending order and return None.
#
#     The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#     order of two equal elements is maintained).
#
#     If a key function is given, apply it once to each list item and sort them,
#     ascending or descending, according to their function values.
#
#     The reverse flag can be set to sort in descending order.

# %%
cc
# Out:
# [113, 112, 110, 3, 2, 1]

# %%
cc.index(3)
# Out:
# 3

# %%
# tuples
x = (12, 13, 14)

# %%
# set
a = {1}

# %%
#
a.update{(12,13,3)}
a

# %%
sq = lamba x: x**2
# Out:
#   File "<ipython-input-79-d1224c306569>", line 1
#     sq = lamba x: x**2
#                ^
# SyntaxError: invalid syntax

# %%
# PANDAS
import pandas as pd
import numpy as np

x = np.random.randn(5, 4)
df = pd.DataFrame (x, columns='A B C D' .split( ))
df.head()
# Out:
#           A         B         C         D
# 0  0.948435 -0.385352 -1.189740  0.947185
# 1 -1.619385 -1.719643  0.651180  0.304821
# 2 -1.671770 -0.488139  0.130647  0.815200
# 3  1.536432  0.257620 -0.031899 -0.633680
# 4  1.808776  1.581584 -0.988406 -0.337515
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['B'].plot(kind='hist', bins=20, title='B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['D'].plot(kind='hist', bins=20, title='D')
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns. load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
logic = data['sex']=='male'
data[logic] ['sex']. count(),891-data [logic] ['sex']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
data['sex'].value_counts()/891*100
# Out:
# male      64.758698
# female    35.241302
# Name: sex, dtype: float64

# %%
sns.countplot(x='sex', data = data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='survived', data = data,hue='sex' )
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.kdeplot(data['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(data['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.barplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.lineplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
data['fare'].skew()
# Out:
# 4.787316519674893

# %%
data = sns. load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_22['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['petal_length'].plot(kind='hist', bins=20, title='petal_length')
# ...

# %%
data['petal_width'].skew()
# Out:
# -0.10296674764898116

# %%
sns.histplot(data['petal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.kdeplot(data['petal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      float64
#  1   B       5 non-null      float64
#  2   C       5 non-null      float64
#  3   D       5 non-null      float64
# dtypes: float64(4)
# memory usage: 288.0 bytes

# %%
import numpy as np


arr = np.array([1,2,3]),  ndmin = [10])

arr.ndim, arr. shape
# Out:
#   File "<ipython-input-9-7085e9325416>", line 4
#     arr = np.array([1,2,3]),  ndmin = [10])
#                                           ^
# SyntaxError: unmatched ')'

# %%
arr2 =np.array(([1,2],[3,4]))
arr2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2.shape, arr2.size, arr2.ndim, arr2.dtype, arr2.itemsize
# Out:
# ((2, 2), 4, 2, dtype('int64'), 8)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('flights')
df.sample(3)
# Out:
#     year month  passengers
# 7   1949   Aug         148
# 88  1956   May         318
# 70  1954   Nov         203

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.loc

# %%
df. sample()
# Out:
#     year month  passengers
# 30  1951   Jul         199

# %%
df.to_csv('flights.csv' , index=False)

# %%
#09/01/2025

# Load Iris data from sklearn
from sklearn.datasets import load_iris
import pandas as pd

#Load the iris dataset
imported = load_iris()

#create a pandas DataFrame from data
iris_df = pd.DataFrame(data=imported.data,
                       columns=imported.feature_names)

# add the target variableto the DataFrame
#iris_df['target'] = imported.target

# Display the first few rows of the DataFrame
print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 102                7.1               3.0                5.9               2.1
# 66                 5.6               3.0                4.5               1.5
# 131                7.9               3.8                6.4               2.0
# 128                6.4               2.8                5.6               2.1
# 29                 4.7               3.2                1.6               0.2
# 121                5.6               2.8                4.9               2.0
# 139                6.9               3.1                5.4               2.1
# 8                  4.4               2.9                1.4               0.2
# 36                 5.5               3.5                1.3               0.2
# 89                 5.5               2.5                4.0               1.3

# %%
imported.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# my target is sepal length
x = iris_df[["petal length (cm)", "sepal width (cm)", "petal width (cm)"]]
y = iris_df["sepal length (cm)"]

# %%
# impport necessory libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#split data

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# model selection
mymodel = LinearRegression()

#Model Training
mymodel.fit(X_train, y_train)

# Model evaluation
y_pred = mymodel.predict(X_test)

# %%
# y = mx+c

# %%
# evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-aa83b87582ea> in <cell line: 3>()
#       1 # evaluate the model
#       2 mse = mean_squared_error(y_test, y_pred)
# ----> 3 rmse = mean_squared_error(y_test, y_pred, squared=False)
#       4 r2 = r2_score(y_test, y_pred)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     192
#     193             # Map *args/**kwargs to the function signature
# --> 194             params = func_sig.bind(*args, **kwargs)
#     195             params.apply_defaults()
#     196
#
# /usr/lib/python3.10/inspect.py in bind(self, *args, **kwargs)
#    3184         if the passed arguments can not be bound.
#    3185         """
# -> 3186         return self._bind(args, kwargs)
#    3187
#    3188     def bind_partial(self, /, *args, **kwargs):
#
# ...

# %%
#logistic diabetes

# %%
from sk learn.datasets import load_diabetes
imported = load_diabetes()
print (imported).DESCR()
# Out:
#   File "<ipython-input-28-4be277be6567>", line 1
#     from sk learn.datasets import load_diabetes
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# using KNN

# %%
from sklearn.neighbours import KNeighborsClassifier

knn = KNeighborsClassifier(

# %%
import pandas as pd
# make DataFrame of the given data
d = pd.DataFrame({"A":[1,2,4,1,2,4],
                     "B":[4,5,6,7,8,9],
                     "C":[-0.2,0,0,0,0,0],
                     "D":[1,1,1,1,1,1]})

# %%
d.var()
# Out:
# A    1.866667
# B    3.500000
# C    0.006667
# D    0.000000
# dtype: float64

# %%
###it will check for cols with var 2.0
from sklearn.feature_selection import VarianceThreshold
data = VarianceThreshold(threshold=2.0)
data.fit_transform(d)
# Out:
# array([[4.],
#        [5.],
#        [6.],
#        [7.],
#        [8.],
#        [9.]])

# %%
data.get_support()
# Out:
# array([False,  True, False, False])

# %%
constant_columns = [column for column in d.columns
                    if column not in d.columns[data.get_support()]]

print(len(constant_columns))
# Out:
# 3

# %%
for feature in constant_columns:
print(feature)
# Out:
#   File "<ipython-input-30-43c4d571204d>", line 2
#     print(feature)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
d.drop(constant_columns,axis=1, inplace=True)

# %%
d
# Out:
#    A  B    C  D
# 0  1  4 -0.2  1
# 1  2  5  0.0  1
# 2  4  6  0.0  1
# 3  1  7  0.0  1
# 4  2  8  0.0  1
# 5  4  9  0.0  1

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
from os import read
df = pd.read_csv('https://ibmice.s3.us-east-1.amazonaws.com/datasets/satander.csv , nrows=1000
# Out:
#   File "<ipython-input-37-f1f4139d327e>", line 2
#     df = pd.read_csv('https://ibmice.s3.us-east-1.amazonaws.com/datasets/satander.csv , nrows=1000
#                      ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
X=df.drop(labels=['TARGET'], axis=1)
y=df['TARGET']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b8dd18d2a38b> in <cell line: 1>()
# ----> 1 X=df.drop(labels=['TARGET'], axis=1)
#       2 y=df['TARGET']
#
# NameError: name 'df' is not defined

# %%
fromsklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
#   File "<ipython-input-40-9bb6d2eee38f>", line 1
#     fromsklearn.model_selection import train_test_split
#                                 ^
# SyntaxError: invalid syntax

# %%
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d64add303c04> in <cell line: 2>()
#       1 var_thres=VarianceThreshold(threshold=0)
# ----> 2 var_thres.fit(X_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# var_thres.get_support()
# #the get_support returns a boolean vector where true means that

# %%
###finding non constant features -- no variance features
sum(var_thres.get_support()), (df.shape[1]-1)-sum var_thres.get_support
# Out:
#   File "<ipython-input-44-fa68f502443c>", line 2
#     sum(var_thres.get_support()), (df.shape[1]-1)-sum var_thres.get_support()
#                                                       ^
# SyntaxError: invalid syntax

# %%
(df.shape[])

# %%
from ast import increment_lineno
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#Loading the dataset
x = load_boston()
df = pd.DataFrame(x.data, columns=x.feature_names)
df["MEDV"] = x.target
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3c712f8b1bb4> in <cell line: 3>()
#       1 from ast import increment_lineno
#       2 #importing libraries
# ----> 3 from sklearn.datasets import load_boston
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/__init__.py in __getattr__(name)
#     159             """
#     160         )
# --> 161         raise ImportError(msg)
#     162     try:
#     163         return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# ...

# %%
def Core(dataset, threshold):

# %%
df=pd.read_csv(url , nrows=1000)
X=df.drop(labels=['TARGET'], axis=1)
y=df['TARGET']
# seperate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.3,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-45537b301cf0> in <cell line: 1>()
# ----> 1 df=pd.read_csv(url , nrows=1000)
#       2 X=df.drop(labels=['TARGET'], axis=1)
#       3 y=df['TARGET']
#       4 # seperate dataset into train and test
#       5 X_train, X_test, y_train, y_test = train_test_split(X,y,
#
# NameError: name 'pd' is not defined

# %%
corr_features = core(data, 0.9)
len(set(corr_features))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6e2db1a6b90a> in <cell line: 1>()
# ----> 1 corr_features = core(data, 0.9)
#       2 len(set(corr_features))
#
# NameError: name 'core' is not defined

# %% [markdown]
# 156
